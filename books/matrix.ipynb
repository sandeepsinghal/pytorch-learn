# %%
import torch

# %%
# 4 rows and 1 column
X = torch.tensor([
    [10, 20, 30],
    [38, 38, 58],
    [11, 21, 31],
    [121, 131, 141]
])

# %%
X.shape
# Out:
# torch.Size([4, 3])

# %%
X.size()
# Out:
# torch.Size([4, 3])

# %%
X[0]
# Out:
# tensor([10, 20, 30])

# %%
X[0, 0]
# Out:
# tensor(10)

# %%
X[2, :]
# Out:
# tensor([11, 21, 31])

# %%
X[2,1]
# Out:
# tensor(21)
